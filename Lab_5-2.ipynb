# %% [markdown]
# # 2. Divide and Conquer (Sorting)

# %% [markdown]
# - **Created by Dr. Ajay

# %% [markdown]
# Write a python program to perform **selection sort**.
# - ** -Algorithm
# * Step 1: Read the number of elements for the list from the user.
# * Step 2: Using for loop insert the elements in the list.
# * Step 3: Initialize the minimum element as min=numbers[i].
# * Step 4: Using the swap method the elements are sorted accordingly.
# * Step 5: Print the sorted list.

# %%
#write code for above cell and compute the running time and also plot graph.
import time
import matplotlib.pyplot as plt
import random


n=int(input("Enter the no of elements:"))
list=[]
for i in range(n):
  x=int(input("Enter the value of element:"))
  list.append(x)
for i in range(n):
  min=list[i]
  for j in range(i+1,n):
    if list[j]<min:
      min=list[j]
      list[i],list[j]=list[j],list[i]

print(list)

sizes = []
times = []
for n in range(100, 1100, 100):
    sizes.append(n)
    lst = []
    for i in range(n):
        lst.append(random.randint(1, 1000))
    start = time.time()
    for i in range(n):
        min = lst[i]
        for j in range(i + 1, n):
            if lst[j] < min:
                min = lst[j]
                lst[i], lst[j] = lst[j], lst[i]

    end = time.time()
    times.append(end - start)
print("Input Size\tTime Taken (seconds)")
for i in range(len(sizes)):
    print(sizes[i], "\t\t", times[i])
plt.plot(sizes, times, marker='o')
plt.xlabel("Number of Elements (n)")
plt.ylabel("Running Time (seconds)")
plt.title("Selection Sort Time Complexity")
plt.grid(True)
plt.show()
# Out:
# Enter the no of elements:5
# Enter the value of element:2
# Enter the value of element:4
# Enter the value of element:1
# Enter the value of element:8
# Enter the value of element:6
# [1, 2, 4, 6, 8]
# Input Size	Time Taken (seconds)
# 100 		 0.0010230541229248047
# 200 		 0.005442619323730469
# 300 		 0.009922027587890625
# 400 		 0.015955686569213867
# 500 		 0.02518320083618164
# 600 		 0.03746294975280762
# 700 		 0.049828529357910156
# 800 		 0.06452059745788574
# 900 		 0.07913804054260254
# 1000 		 0.09418773651123047

# %% [markdown]
# In computer science, **merge sort** (also commonly spelled mergesort) is an efficient, general-purpose, comparison-based sorting algorithm. Most implementations produce a stable sort, which means that the order of equal elements is the same in the input and output. Merge sort is a divide and conquer algorithm that was invented by John von Neumann in 1945.
# Write a Python program to sort the elements using **merge sort** and plot a graph to the time taken versus n
# - Algorithm(Merge Sort is a divide and conquer algorithm. It divides	input array in two halve.s, calls itself for the two halves and then merges two sorted halves.)
# 1.	Divide the unsorted array into n partitions, each	partition contains 1 element.
# 2.	Repeatedly merge partitioned units to produce	new sublists until there is only l sublist remaining. This will be the sorted	.
# 3.	Compare the first element of the sublist with the first element of the sublist to its right.
# 4.	Merge the two sublists by	paring each element of the sublist and placing the smaller element into the	new sublist.
# 5.	Repeat step 3 and 4 untill	all sublists are merged into a single sorted sublist.

# %%
#write code for above cell and compute the running time and also plot graph.
import time
import random
import matplotlib.pyplot as plt

def merge(left, right):
    result = []
    i = j = 0

    while i < len(left) and j < len(right):
        if left[i] <= right[j]:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1

    result.extend(left[i:])
    result.extend(right[j:])
    return result

def merge_sort(arr):
    if len(arr) <= 1:
        return arr

    mid = len(arr) // 2
    left = merge_sort(arr[:mid])
    right = merge_sort(arr[mid:])

    return merge(left, right)

sizes = []
times = []
for n in range(50, 1100, 100):
    sizes.append(n)
    arr = []
    for i in range(n):
        arr.append(random.randint(1, 1000))
    start = time.time()
    sorted_arr = merge_sort(arr)
    end = time.time()
    times.append(end - start)
print("Input Size\tTime Taken (seconds)")
for i in range(len(sizes)):
    print(sizes[i], "\t\t", times[i])
plt.plot(sizes, times, marker='o')
plt.xlabel("Number of Elements (n)")
plt.ylabel("Time Taken (seconds)")
plt.title("Merge Sort Time Complexity")
plt.grid(True)
plt.show()
# Out:
# Input Size	Time Taken (seconds)
# 50 		 0.00010371208190917969
# 150 		 0.0002434253692626953
# 250 		 0.00041675567626953125
# 350 		 0.0006511211395263672
# 450 		 0.0011861324310302734
# 550 		 0.0010707378387451172
# 650 		 0.0013175010681152344
# 750 		 0.0018112659454345703
# 850 		 0.001997709274291992
# 950 		 0.002544403076171875
# 1050 		 0.0029036998748779297

# %% [markdown]
# **Quicksort** (sometimes called partition-exchange sort) is an efficient sorting algorithm. Developed by British computer scientist Tony Hoare in 1959 and published in 1961, it is still a commonly used algorithm for sorting.
#
# Quicksort is a divide-and-conquer algorithm. It works by selecting a 'pivot' element from the array and partitioning the other elements into two sub-arrays, according to whether they are less than or greater than the pivot. The sub-arrays are then sorted recursively. This can be done in-place, requiring small additional amounts of memory to perform the sorting.
# Write a Python program to sort the elements using quick sort and plot a graph to the time taken versus n.
# - Algorithm
# 1.	Select a pivot element from the array.
# 2.	Partition the array into two sub-arrays. The elements in the first sub-array are less than the pivot element, while the elements in the second sub-array are greater than the pivot element.
# 3.	Recursively sort the sub-arrays created in Step 2.
# 4.	Join the sub-arrays and the pivot element together to	the sorted array.

# %%
#write code for above cell and compute the running time and also plot graph.
import time
import random
import matplotlib.pyplot as plt

def quick_sort(arr):
    if len(arr) <= 1:
        return arr

    pivot = arr[len(arr) // 2]
    left = []
    right = []
    equal = []

    for x in arr:
        if x < pivot:
            left.append(x)
        elif x > pivot:
            right.append(x)
        else:
            equal.append(x)

    return quick_sort(left) + equal + quick_sort(right)

sizes = []
times = []

for n in range(10, 1000, 50):
    sizes.append(n)

    arr = []
    for i in range(n):
        arr.append(random.randint(1, 1000))

    start = time.time()
    sorted_arr = quick_sort(arr)
    end = time.time()

    times.append(end - start)

print("Input Size\tTime Taken (seconds)")
for i in range(len(sizes)):
    print(sizes[i], "\t\t", times[i])

plt.plot(sizes, times, marker='o')
plt.xlabel("Number of Elements (n)")
plt.ylabel("Time Taken (seconds)")
plt.title("Quick Sort Time Complexity")
plt.grid(True)
plt.show()
# Out:
# Input Size	Time Taken (seconds)
# 10 		 1.9788742065429688e-05
# 60 		 8.654594421386719e-05
# 110 		 0.0001361370086669922
# 160 		 0.0008821487426757812
# 210 		 0.00020837783813476562
# 260 		 0.00021719932556152344
# 310 		 0.0003247261047363281
# 360 		 0.00031280517578125
# 410 		 0.000385284423828125
# 460 		 0.0004305839538574219
# 510 		 0.0005114078521728516
# 560 		 0.0004956722259521484
# 610 		 0.0005695819854736328
# 660 		 0.0005698204040527344
# 710 		 0.0006864070892333984
# 760 		 0.0007574558258056641
# 810 		 0.0007271766662597656
# 860 		 0.0007526874542236328
# 910 		 0.0007867813110351562
# 960 		 0.0008549690246582031

# %% [markdown]
# ### Experiment: compare sorting algorithms

# %%
# Experiment variables
n_list = [1000, 2000, 5000, 10000, 20000, 50000, 100000, 200000]
n_max = n_list[len(n_list) -1]
import time
import random
import matplotlib.pyplot as plt

def quick_sort(arr):
    if len(arr) <= 1:
        return arr

    pivot = arr[len(arr) // 2]
    left = []
    right = []
    equal = []

    for x in arr:
        if x < pivot:
            left.append(x)
        elif x > pivot:
            right.append(x)
        else:
            equal.append(x)

    return quick_sort(left) + equal + quick_sort(right)

n_list = [1000, 2000, 5000, 10000, 20000, 50000, 100000, 200000]
times = []

for n in n_list:
    arr = []
    for i in range(n):
        arr.append(random.randint(1, n))

    start = time.time()
    quick_sort(arr)
    end = time.time()

    times.append(end - start)

print("Input Size\tTime Taken (seconds)")
for i in range(len(n_list)):
    print(n_list[i], "\t\t", times[i])

plt.plot(n_list, times, marker='o')
plt.xlabel("Number of Elements (n)")
plt.ylabel("Time Taken (seconds)")
plt.title("Quick Sort Time Complexity")
plt.grid(True)
plt.show()
# Out:
# Input Size	Time Taken (seconds)
# 1000 		 0.0009784698486328125
# 2000 		 0.0026340484619140625
# 5000 		 0.005711078643798828
# 10000 		 0.012941837310791016
# 20000 		 0.0271456241607666
# 50000 		 0.07535314559936523
# 100000 		 0.17286920547485352
# 200000 		 0.4436042308807373

# %%
# Creating a random value (uniform)

import random

numbers = [random.randint(0, 999) for _ in range(n_max)]
numbers = [random.randint(0, 999) for _ in range(n_max)]
numbers = [random.randrange(1000) for _ in range(n_max)]

# %%
import timeit
a_time = []
b_time = []
c_time = []

for l in n_list:
   a = numbers[:l]
   b = numbers[:l]
   c = numbers[:l]

start_time = timeit.default_timer()
quick_sort(a)
a_time.append((timeit.default_timer() - start_time) * 1000)

start_time = timeit.default_timer()
merge_sort(b)
b_time.append((timeit.default_timer() - start_time) * 1000)

start_time = timeit.default_timer()
selection.sort(c)
c_time.append((timeit.default_timer() - start_time) * 1000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-268988830.py in <cell line: 0>()
#      18
#      19 start_time = timeit.default_timer()
# ---> 20 selection.sort(c)
#      21 c_time.append((timeit.default_timer() - start_time) * 1000)
#
# NameError: name 'selection' is not defined

# %%
# Plotting results
import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize=(10, 5))
plt.plot(a_time, linewidth = 1, marker="o")
plt.plot(b_time, linewidth = 1, marker="o")
plt.plot(c_time, linewidth = 1, marker="o")
plt.xticks(np.arange(len(n_list)), n_list)
plt.title("Compare Sorting Algorithms", fontsize = 14)
plt.ylabel('Time (ms)')
plt.xlabel('n')
plt.legend(["Quicksort", "Mergesort", "Selection sort"], loc = "best")
plt.show()
